# %%
class Deque:

  def __init__(self):
    self.my_list = []

  def is_empty(self):
    if len(self.my_list) == 0:
      print("Deque is empty")
    else:
      print("Deque is not empty")

  def front_insert(self,data):
    self.my_list.append(data)

  def rear_insert(self,data):
    if len(self.my_list) != 0:
      self.my_list.insert(0,data)
    else:
      self.front_deque()

  def delete_front(self):
    if len(self.my_list) != 0:
      self.my_list.pop()
    else:
      raise IndexError("Deque is Empty")

  def delete_rear(self):
    if len(self.my_list) != 0:
      self.my_list.pop(0)

  def total_items(self):
    print("Total Items is ",len(self.my_list))


  def get_front(self):
    print("The front item is ",self.my_list[0])


  def get_rear(self):
    print("The rear item is ",self.my_list[-1])

# %%
d1 = Deque()
d1.front_insert(10)
d1.front_insert(20)
d1.front_insert(30)
d1.rear_insert(70)
d1.rear_insert(60)
d1.rear_insert(50)
d1.rear_insert(40)
d1.total_items()
d1.get_front()
d1.get_rear()
d1.delete_rear()
d1.delete_front()
print()
d1.total_items()
d1.get_front()
d1.get_rear()
# Out:
# Total Items is  7
# The front item is  40
# The rear item is  30
#
# Total Items is  5
# The front item is  50
# The rear item is  20
